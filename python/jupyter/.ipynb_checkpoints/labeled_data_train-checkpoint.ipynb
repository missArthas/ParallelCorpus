# %%
import pandas as pd

# %%
data = pd.read_csv("/home/kevin/github/ParallelCorpus/trainData/result.csv")
data.describe()
data.loc[data['lineCmp']>3,'label']=0

# %%
data.describe()
label0 = data[data['label']==0]
print(len(label0))
label1 = data[data['label']==1]
print(len(label1))
# Out:
# 39
# 101

# %%
data.head()
# Out:
#     lineCmp  sameLineCmp    charCmp   wordCmp  label
# 0  4.000000          0.0  13.675000  6.431579      0
# 1  6.803922          0.0  13.383657  4.560440      0
# 2  0.994030          0.0   3.505904  1.118302      1
# 3  6.955224          0.0  21.149533  8.290657      0
# 4  1.219219          0.0   4.929293  1.666200      0

# %%
data = label0.append(label1)
print(len(data))
y = data['label']
X = data.loc[:,['lineCmp', 'sameLineCmp', 'charCmp', 'wordCmp'] ]
X.describe()
# Out:
# 3223
#            lineCmp  sameLineCmp      charCmp      wordCmp
# count  3223.000000  3223.000000  3223.000000  3223.000000
# mean      2.270372     0.018341     4.915252     2.561369
# std       4.114011     0.057953     7.070700     3.632411
# min       0.038660     0.000000     0.096347     0.065842
# 25%       0.972973     0.000000     1.631670     0.981949
# 50%       1.081967     0.002567     2.225817     1.095609
# 75%       2.008438     0.004697     4.284002     2.260906
# max      55.000000     1.000000    75.641935    32.203488

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import cross_validation
# Out:
# /home/kevin/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
clf = DecisionTreeClassifier(max_depth=4)
X_train, X_test, Y_train, Y_test = cross_validation.train_test_split(X, y, test_size=0.25, random_state=0)
# X = [[0, 0], [1, 1],[0,1],[1,0]]
# y = [0, 1, 1, 0]
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
clf.score(X_test,Y_test)
# Out:
# 0.9813895781637717

# %%
clf.predict([[0.7204301075268817,0.0,1.263157894736842,0.543509272467903]])
# Out:
# array([0])

# %%
clf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.datasets import load_iris
from sklearn import tree
import sys
import os 
from IPython.display import Image  
dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=['lineCmp', 'sameLineCmp', 'charCmp', 'wordCmp'],
                         class_names=['0', '1'],  
                         filled=True, rounded=True)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png()) 


# iris.target_names

# %%
from sklearn.datasets import load_iris
from sklearn import tree
import sys
import os

iris = load_iris()
clf = tree.DecisionTreeClassifier()
clf = clf.fit(iris.data, iris.target)
with open("iris.dot", 'w') as f:
    f = tree.export_graphviz(clf, out_file=f)

# %%
import pydotplus
from sklearn import tree
from IPython.display import Image 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())

# %%
pwd（）
# Out:
# '/Users/nali/jupyter/ParallelCorpus'
